# %%
#link half true https://www.politifact.com/factchecks/list/?page=2&ruling=half-true
URL = 'https://www.politifact.com/factchecks/list/?page='+ pgno +'&ruling=half-true'

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import requests
import urllib.request
import time

authors = []
dates = []
statements = []
content = []
sources = []
targets = []

# %%
def scrape_website(page_number):
  pgno = str(page_number)
  URL = 'https://www.politifact.com/factchecks/list/?page='+ pgno +'&ruling=half-true'
  webpage = requests.get(URL)
  soup = BeautifulSoup(webpage.text,'html.parser')
  #Get location
  statement_footer = soup.find_all('footer',attrs ={'class':'m-statement__footer'})
  statement_quote = soup.find_all('div',attrs={'class':'m-statement__quote'})
  statement_meta = soup.find_all('div',attrs={'class':'m-statement__meta'})
  target = soup.find_all('div',attrs={'class':'m-statement__meter'})

  for i in statement_footer:
    link1 = i.text.strip()
    name_and_date = link1.split()
    first_name = name_and_date[1]
    last_name = name_and_date[2]
    full_name = first_name+' '+last_name
    month = name_and_date[4]
    day = name_and_date[5]
    year = name_and_date[6]
    date = month + ' '+ day + ' '+year
    dates.append(date)
    authors.append(full_name)

  for i in statement_quote:
    link2 = i.find_all('a')
    statement_text = link2[0].text.strip()
    statements.append(statement_text)
    atag=i.find_all('a')[0]
    link2 = i.find_all('a')
    statement_text = link2[0].text.strip()
    URL2 = 'https://www.politifact.com' +  atag['href']
    webpage = requests.get(URL2)
    soup2 = BeautifulSoup(webpage.text)
    statement_content = soup2.find_all('article',attrs={'class':'m-textblock'})
    content.append(''.join(statement_content[0].text.strip().splitlines()))


  for i in statement_quote:
   atag=i.find_all('a')[0]   

  for i in statement_meta:
    link3 = i.find_all('a')
    source_text = link3[0].text.strip()
    sources.append(source_text)

  for i in target:
      link4 = i.find('div',attrs={'class':'c-image'}).find('img').get('alt')
      targets.append(link4)

# %%
n = 10
for i in range(1,n):
  scrape_website(i)

# %%
data = pd.DataFrame(columns = ['author','statement','article','source','date','target'])
data['author'] = pd.Series(authors)
data['statement']= pd.Series(statements)
data['source']= pd.Series(sources)
data['article'] = pd.Series(content)
data['date']= pd.Series(dates)
data['target']= pd.Series(targets)

data
# Out:
#                     author                                          statement  \
# 0           Louis Jacobson  “We created more new jobs in two years than an...
# 1               D.L. Davis  "During my time in office, we've increased per...
# 2              Yacob Reyes  "(Ron) DeSantis' bill would remove: background...
# 3       Samantha Putterman  “Female student-athletes in Florida need to pr...
# 4            Maria Ramirez  "Under Biden, we have seen over 4.6 million en...
# ..                     ...                                                ...
# 265            Amy Sherman  Says the American Civil Liberties Union oppose...
# 266          Jon Greenberg  “There’s about 9% of (the American Rescue Plan...
# 267         Louis Jacobson              “I have never sued a nun — any nuns.”
# 268  Kiannah Sepeda-Miller  “For the month of February, Illinois has been ...
# 269             Eric Litke  “On average, 17% of a family’s income goes tow...
#
#                                                article           source  \
# 0    President Joe Biden has regularly touted how w...        Joe Biden
# 1    Does school aid make a difference in student p...       Tony Evers
# 2    As California’s Democratic governor, Gavin New...     Gavin Newsom
# 3    UPDATE 2/9: Public outcry over menstrual quest...           Tweets
# 4    In an effort to limit southwest border crossin...         Chip Roy
# ..                                                 ...              ...
# 265  A major Democratic bill that aims to expand vo...   Ronna McDaniel
# 266  A North Carolina congressman claims the Democr...         Ted Budd
# 267  Critics of Xavier Becerra, President Joe Biden...   Xavier Becerra
# 268  Illinois kicked off February with one of the l...      JB Pritzker
# 269  Access to affordable child care is one of many...  Sarah Godlewski
#
#                   date     target
# 0     February 7, 2023  half-true
# 1     February 7, 2023  half-true
# 2     February 6, 2023  half-true
# 3     February 3, 2023  half-true
# 4        • February 3,  half-true
# ..                 ...        ...
# 265      March 1, 2021  half-true
# 266      March 1, 2021  half-true
# 267  February 26, 2021  half-true
# 268  February 25, 2021  half-true
# 269  February 23, 2021  half-true
#
# [270 rows x 6 columns]

# %%
data.to_csv("New_HalfTrue.csv")
